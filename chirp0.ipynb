# %%
import sympy as sp
# write the equation for a chearp function where the frequency increases linearly with time
t=sp.symbols('t')
f=1+2*t
x=sp.sin(2*sp.pi*f*t)
# plot the function
sp.plot(x,(t,0,5))
plt.show()

# %%
X = sp.fourier_transform(x, t, sp.symbols('f', real=True))

# %%
# plot the magnitude of the fourier transform
XX=abs(X)
